# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %cd "C:\Users\akans\OneDrive\Documents"
# Out:
# C:\Users\akans\OneDrive\Documents

# %%
data = pd.read_csv("creditcard.csv")
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.918649e-15  5.682686e-16 -8.761736e-15  2.811118e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552103e-15  2.040130e-15 -1.698953e-15 -1.893285e-16 -3.147640e-15
# ...

# %%
data.shape
# Out:
# (284807, 31)

# %%
data.Class.value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
data.corr()
# Out:
#             Time            V1            V2            V3            V4  \
# Time    1.000000  1.173963e-01 -1.059333e-02 -4.196182e-01 -1.052602e-01
# V1      0.117396  1.000000e+00  4.135835e-16 -1.227819e-15 -9.215150e-16
# V2     -0.010593  4.135835e-16  1.000000e+00  3.243764e-16 -1.121065e-15
# V3     -0.419618 -1.227819e-15  3.243764e-16  1.000000e+00  4.711293e-16
# V4     -0.105260 -9.215150e-16 -1.121065e-15  4.711293e-16  1.000000e+00
# V5      0.173072  1.812612e-17  5.157519e-16 -6.539009e-17 -1.719944e-15
# V6     -0.063016 -6.506567e-16  2.787346e-16  1.627627e-15 -7.491959e-16
# V7      0.084714 -1.005191e-15  2.055934e-16  4.895305e-16 -4.104503e-16
# V8     -0.036949 -2.433822e-16 -5.377041e-17 -1.268779e-15  5.697192e-16
# V9     -0.008660 -1.513678e-16  1.978488e-17  5.568367e-16  6.923247e-16
# V10     0.030617  7.388135e-17 -3.991394e-16  1.156587e-15  2.232685e-16
# V11    -0.247689  2.125498e-16  1.975426e-16  1.576830e-15  3.459380e-16
# ...

# %%
sns.countplot('Class',data=data).set(title="no. of 0's vs no. of 1's")
# Out:
# C:\Users\akans\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0.5, 1.0, "no. of 0's vs no. of 1's")]

# %%
data.drop('Time',axis=1,inplace = True)
data
# Out:
#                V1         V2        V3        V4        V5        V6  \
# 0       -1.359807  -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1        1.191857   0.266151  0.166480  0.448154  0.060018 -0.082361
# 2       -1.358354  -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3       -0.966272  -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4       -1.158233   0.877737  1.548718  0.403034 -0.407193  0.095921
# ...           ...        ...       ...       ...       ...       ...
# 284802 -11.881118  10.071785 -9.834783 -2.066656 -5.364473 -2.606837
# 284803  -0.732789  -0.055080  2.035030 -0.738589  0.868229  1.058415
# 284804   1.919565  -0.301254 -3.249640 -0.557828  2.630515  3.031260
# 284805  -0.240440   0.530483  0.702510  0.689799 -0.377961  0.623708
# 284806  -0.533413  -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
#               V7        V8        V9       V10  ...       V21       V22  \
# ...

# %%
plt.figure(figsize=(12,7))
sns.heatmap(data.corr())
# Out:
# <AxesSubplot:>

# %%
cols = data.columns.tolist()
cols = [c for c in cols if c not in ["Class"]]
target = "Class"
x=data[cols]
y=data[target]

# %% [markdown]
# # Logistic Regression

# %%
from sklearn import neighbors,metrics
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.10, random_state=42)

lr_model = LogisticRegression()
lr_model.fit(xtrain, ytrain)
y_pred_lr = lr_model.predict(xtest)
# Out:
# C:\Users\akans\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
accuracy_lr = accuracy_score(ytest, y_pred_lr)
precision_lr = precision_score(ytest, y_pred_lr)
recall_lr = recall_score(ytest, y_pred_lr)
f1_lr = f1_score(ytest, y_pred_lr)
roc_auc_lr = roc_auc_score(ytest, y_pred_lr)

# %%
print("LogisticRegression: \n")
print("Accuracy:",accuracy_lr)
print("Precision:",precision_lr)
print("Recall:",recall_lr)
print("F1 Score:",f1_lr)
print("roc-auc",roc_auc_lr)
# Out:
# LogisticRegression:
#
# Accuracy: 0.9991222218320986
# Precision: 0.8
# Recall: 0.6086956521739131
# F1 Score: 0.6913580246913581
# roc-auc 0.804224738342979

# %%
from sklearn.metrics import confusion_matrix

matrix = confusion_matrix(ytest, y_pred_lr)
cm = pd.DataFrame(matrix, index=['not_fraud', 'fraud'], columns=['not_fraud', 'fraud'])

sns.heatmap(cm, annot=True, cbar=None, cmap="Blues", fmt = 'g')

plt.title("Confusion Matrix of Logistic Regression")
plt.tight_layout()
plt.ylabel("True Class")
plt.xlabel("Predicted Class")
plt.show()

# %% [markdown]
# # KNN

# %%
from sklearn import neighbors,metrics
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.10, random_state=42)

knn=neighbors.KNeighborsClassifier(n_neighbors=25,weights='uniform')
knn.fit(xtrain,ytrain)
# Out:
# KNeighborsClassifier(n_neighbors=25)

# %%
y_pred_knn=knn.predict(xtest)

# %%
accuracy_knn = accuracy_score(ytest, y_pred_knn)
precision_knn = precision_score(ytest, y_pred_knn)
recall_knn = recall_score(ytest, y_pred_knn)
f1_knn = f1_score(ytest, y_pred_knn)
roc_auc_knn = roc_auc_score(ytest, y_pred_knn)

# %%
print("KNN: \n")
print("Accuracy:",accuracy_knn)
print("Precision:",precision_knn)
print("Recall:",recall_knn)
print("F1 Score:",f1_knn)
print ("roc-auc-:",roc_auc_knn)
# Out:
# KNN:
#
# Accuracy: 0.9990519995786665
# Precision: 0.9130434782608695
# Recall: 0.45652173913043476
# F1 Score: 0.608695652173913
# roc-auc-: 0.7282257016383668

# %%
from sklearn.metrics import confusion_matrix

matrix = confusion_matrix(ytest, y_pred_knn)
cm = pd.DataFrame(matrix, index=['not_fraud', 'fraud'], columns=['not_fraud', 'fraud'])

sns.heatmap(cm, annot=True, cbar=None, cmap="Blues", fmt = 'g')

plt.title("Confusion Matrix of KNN")
plt.tight_layout()
plt.ylabel("True Class")
plt.xlabel("Predicted Class")
plt.show()

# %% [markdown]
# # SVM

# %%
from sklearn.svm import SVC

svm_model = SVC()
svm_model.fit(xtrain, ytrain)
y_pred_svm = svm_model.predict(xtest)

# %%
accuracy_svm = accuracy_score(ytest, y_pred_svm)
precision_svm = precision_score(ytest, y_pred_svm)
recall_svm = recall_score(ytest, y_pred_svm)
f1_svm = f1_score(ytest, y_pred_svm)
roc_auc_svm = roc_auc_score(ytest, y_pred_svm)

# %%
print("SVM: \n")
print("Accuracy:",accuracy_svm)
print("Precision:",precision_svm)
print("Recall:",recall_svm)
print("F1 Score:",f1_svm)
print ("roc-auc-:",roc_auc_svm)
# Out:
# SVM:
#
# Accuracy: 0.9988413328183702
# Precision: 0.76
# Recall: 0.41304347826086957
# F1 Score: 0.5352112676056338
# roc-auc-: 0.7064162353498827

# %%
from sklearn.metrics import confusion_matrix

matrix = confusion_matrix(ytest, y_pred_svm)
cm = pd.DataFrame(matrix, index=['not_fraud', 'fraud'], columns=['not_fraud', 'fraud'])

sns.heatmap(cm, annot=True, cbar=None, cmap="Blues", fmt = 'g')

plt.title("Confusion Matrix of SVM")
plt.tight_layout()
plt.ylabel("True Class")
plt.xlabel("Predicted Class")
plt.show()

# %% [markdown]
# # RandomForest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier()
rf_model.fit(xtrain, ytrain)
y_pred_rf = rf_model.predict(xtest)

# %%
accuracy_rf = accuracy_score(ytest, y_pred_rf)
precision_rf = precision_score(ytest, y_pred_rf)
recall_rf = recall_score(ytest, y_pred_rf)
f1_rf = f1_score(ytest, y_pred_rf)
roc_auc_rf = roc_auc_score(ytest, y_pred_rf)

# %%
print("RandomForestClassifier: \n")
print("Accuracy:",accuracy_rf)
print("Precision:",precision_rf)
print("Recall:",recall_rf)
print("F1 Score:",f1_rf)
print ("roc-auc-:",roc_auc_rf)
# Out:
# RandomForestClassifier:
#
# Accuracy: 0.9995435553526912
# Precision: 0.9459459459459459
# Recall: 0.7608695652173914
# F1 Score: 0.8433734939759038
# roc-auc-: 0.8803996146818449

# %%
from sklearn.metrics import confusion_matrix

matrix = confusion_matrix(ytest, y_pred_rf)
cm = pd.DataFrame(matrix, index=['not_fraud', 'fraud'], columns=['not_fraud', 'fraud'])

sns.heatmap(cm, annot=True, cbar=None, cmap="Blues", fmt = 'g')

plt.title("Confusion Matrix of RandomForest Classifier")
plt.tight_layout()
plt.ylabel("True Class")
plt.xlabel("Predicted Class")
plt.show()

# %% [markdown]
# # Resampling Techniques

# %%
print("""We will use some resampling techniques such as:
      1.Undersampling
      2.Smote
      3.Tomek links
      4.Near Miss
      """)
# Out:
# We will use some resampling techniques such as:
#       1.Undersampling
#       2.Smote
#       3.Tomek links
#       4.Near Miss

# %% [markdown]
# # Undersampling using RandomUnderSampler

# %%
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.under_sampling import TomekLinks
from imblearn.under_sampling import NearMiss

# %%
rus = RandomUnderSampler(sampling_strategy='auto', random_state=42)
X_resampled_rus, y_resampled_rus = rus.fit_resample(xtrain, ytrain)

# %%
test = pd.DataFrame(y_resampled_rus, columns = ['Class'])

# %%
fig, axs = plt.subplots(ncols=2, figsize=(13,4.5))
sns.countplot(x="Class", data=data, ax=axs[0])
sns.countplot(x="Class", data=test, ax=axs[1])

fig.suptitle("Class repartition before and after undersampling")
a1=fig.axes[0]
a1.set_title("Before")
a2=fig.axes[1]
a2.set_title("After")
# Out:
# Text(0.5, 1.0, 'After')

# %% [markdown]
# # By RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix
model_rf = RandomForestClassifier(random_state=42)
model_rf.fit(X_resampled_rus, y_resampled_rus)
y_pred_rf = model_rf.predict(xtest)

# %%
print("\RandomForestClassifier by Undersampling using RandomUnderSampler Results:")
print("Confusion Matrix:\n", confusion_matrix(ytest, y_pred_rf))
print("Classification Report:\n", classification_report(ytest, y_pred_rf))
# Out:
# \RandomForestClassifier by Undersampling using RandomUnderSampler Results:
# Confusion Matrix:
#  [[  206 28229]
#  [    0    46]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.01      0.01     28435
#            1       0.00      1.00      0.00        46
#
#     accuracy                           0.01     28481
#    macro avg       0.50      0.50      0.01     28481
# weighted avg       1.00      0.01      0.01     28481

# %%
accuracy_u_rf = accuracy_score(ytest, y_pred_rf)
precision_u_rf = precision_score(ytest, y_pred_rf)
recall_u_rf = recall_score(ytest, y_pred_rf)
f1_u_rf = f1_score(ytest, y_pred_rf)
roc_auc_u_rf = roc_auc_score(ytest, y_pred_rf)

# %%
print("RandomForestClassifier:")
print(f"Accuracy: {accuracy_u_rf:.4f}, Precision: {precision_u_rf:.4f}, Recall: {recall_u_rf:.4f}, F1 Score: {f1_u_rf:.4f}, ROC AUC: {roc_auc_u_rf:.4f}\n")
# Out:
# RandomForestClassifier:
# Accuracy: 0.0088, Precision: 0.0016, Recall: 1.0000, F1 Score: 0.0032, ROC AUC: 0.5036

# %%
from sklearn.metrics import confusion_matrix

matrix = confusion_matrix(ytest, y_pred_rf)
cm = pd.DataFrame(matrix, index=['not_fraud', 'fraud'], columns=['not_fraud', 'fraud'])

sns.heatmap(cm, annot=True, cbar=None, cmap="Blues", fmt = 'g')

plt.title("Confusion Matrix of RandomForest Classifier by RandomUnderSampler")
plt.tight_layout()
plt.ylabel("True Class")
plt.xlabel("Predicted Class")
plt.show()

# %% [markdown]
# # By SVM

# %%
svm_model = SVC()
svm_model.fit(X_resampled_rus, y_resampled_rus)
y_pred_svm = svm_model.predict(xtest)

# %%
print("\nSVM By RandomUnderSampler Results:")
print("Confusion Matrix:\n", confusion_matrix(ytest, y_pred_svm))
print("Classification Report:\n", classification_report(ytest, y_pred_svm))
# Out:
# SVM By RandomUnderSampler Results:
# Confusion Matrix:
#  [[26039  2396]
#  [    9    37]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.92      0.96     28435
#            1       0.02      0.80      0.03        46
#
#     accuracy                           0.92     28481
#    macro avg       0.51      0.86      0.49     28481
# weighted avg       1.00      0.92      0.95     28481

# %%
accuracy_u_svm = accuracy_score(ytest, y_pred_svm)
precision_u_svm = precision_score(ytest, y_pred_svm)
recall_u_svm = recall_score(ytest, y_pred_svm)
f1_u_svm = f1_score(ytest, y_pred_svm)
roc_auc_u_svm = roc_auc_score(ytest, y_pred_svm)

# %%
print("SVM:")
print(f"Accuracy: {accuracy_u_svm:.4f}, Precision: {precision_u_svm:.4f}, Recall: {recall_u_svm:.4f}, F1 Score: {f1_u_svm:.4f}, ROC AUC: {roc_auc_u_svm:.4f}\n")
# Out:
# SVM:
# Accuracy: 0.9156, Precision: 0.0152, Recall: 0.8043, F1 Score: 0.0299, ROC AUC: 0.8600

# %%
from sklearn.metrics import confusion_matrix

matrix = confusion_matrix(ytest, y_pred_svm)
cm = pd.DataFrame(matrix, index=['not_fraud', 'fraud'], columns=['not_fraud', 'fraud'])

sns.heatmap(cm, annot=True, cbar=None, cmap="Blues", fmt = 'g')

plt.title("Confusion Matrix SVM By RandomUnderSampler")
plt.tight_layout()
plt.ylabel("True Class")
plt.xlabel("Predicted Class")
plt.show()

# %% [markdown]
# # By Logistic Regression

# %%
lr_model = LogisticRegression()
lr_model.fit(X_resampled_rus, y_resampled_rus)
y_pred_lr = lr_model.predict(xtest)
# Out:
# C:\Users\akans\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
print("\nLogistic Resgression By RandomUnderSampler Results::")
print("Confusion Matrix:\n", confusion_matrix(ytest, y_pred_lr))
print("Classification Report:\n", classification_report(ytest, y_pred_lr))
# Out:
# Logistic Resgression By RandomUnderSampler Results::
# Confusion Matrix:
#  [[27528   907]
#  [    4    42]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98     28435
#            1       0.04      0.91      0.08        46
#
#     accuracy                           0.97     28481
#    macro avg       0.52      0.94      0.53     28481
# weighted avg       1.00      0.97      0.98     28481

# %%
accuracy_u_lr = accuracy_score(ytest, y_pred_lr)
precision_u_lr = precision_score(ytest, y_pred_lr)
recall_u_lr = recall_score(ytest, y_pred_lr)
f1_u_lr = f1_score(ytest, y_pred_lr)
roc_auc_u_lr = roc_auc_score(ytest, y_pred_lr)

# %%
print("Logistic Regression:")
print(f"Accuracy: {accuracy_u_lr:.4f}, Precision: {precision_u_lr:.4f}, Recall: {recall_u_lr:.4f}, F1 Score: {f1_u_lr:.4f}, ROC AUC: {roc_auc_u_lr:.4f}\n")
# Out:
# Logistic Regression:
# Accuracy: 0.9680, Precision: 0.0443, Recall: 0.9130, F1 Score: 0.0844, ROC AUC: 0.9406

# %%
from sklearn.metrics import confusion_matrix

matrix = confusion_matrix(ytest, y_pred_lr)
cm = pd.DataFrame(matrix, index=['not_fraud', 'fraud'], columns=['not_fraud', 'fraud'])

sns.heatmap(cm, annot=True, cbar=None, cmap="Blues", fmt = 'g')

plt.title("Confusion Matrix Logistic Regression by RandomUnderSampler")
plt.tight_layout()
plt.ylabel("True Class")
plt.xlabel("Predicted Class")
plt.show()

# %% [markdown]
# # By KNN

# %%
knn_model = KNeighborsClassifier()
knn_model.fit(X_resampled_rus, y_resampled_rus)
y_pred_knn = knn_model.predict(xtest)

# %%
print("\nKNN By RandomUnderSampler Results:")
print("Confusion Matrix:\n", confusion_matrix(ytest, y_pred_knn))
print("Classification Report:\n", classification_report(ytest, y_pred_knn))
# Out:
# KNN By RandomUnderSampler Results:
# Confusion Matrix:
#  [[26581  1854]
#  [    4    42]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.93      0.97     28435
#            1       0.02      0.91      0.04        46
#
#     accuracy                           0.93     28481
#    macro avg       0.51      0.92      0.50     28481
# weighted avg       1.00      0.93      0.96     28481

# %%
accuracy_u_knn = accuracy_score(ytest, y_pred_knn)
precision_u_knn = precision_score(ytest, y_pred_knn)
recall_u_knn = recall_score(ytest, y_pred_knn)
f1_u_knn = f1_score(ytest, y_pred_knn)
roc_auc_u_knn = roc_auc_score(ytest, y_pred_knn)

# %%
print("k-Nearest Neighbors (KNN):")
print(f"Accuracy: {accuracy_u_knn:.4f}, Precision: {precision_u_knn:.4f}, Recall: {recall_u_knn:.4f}, F1 Score: {f1_u_knn:.4f}, ROC AUC: {roc_auc_u_knn:.4f}\n")
# Out:
# k-Nearest Neighbors (KNN):
# Accuracy: 0.9348, Precision: 0.0222, Recall: 0.9130, F1 Score: 0.0433, ROC AUC: 0.9239

# %%
from sklearn.metrics import confusion_matrix

matrix = confusion_matrix(ytest, y_pred_knn)
cm = pd.DataFrame(matrix, index=['not_fraud', 'fraud'], columns=['not_fraud', 'fraud'])

sns.heatmap(cm, annot=True, cbar=None, cmap="Blues", fmt = 'g')

plt.title("Confusion Matrix KNN By RandomUnderSampler")
plt.tight_layout()
plt.ylabel("True Class")
plt.xlabel("Predicted Class")
plt.show()

# %% [markdown]
# # Oversampling using SMOTE

# %%
smote = SMOTE(sampling_strategy='auto', random_state=42)
X_resampled_smote, y_resampled_smote = smote.fit_resample(xtrain, ytrain)

# %%
test = pd.DataFrame(y_resampled_smote, columns = ['Class'])

# %%
fig, axs = plt.subplots(ncols=2, figsize=(13,4.5))
sns.countplot(x="Class", data=data, ax=axs[0])
sns.countplot(x="Class", data=test, ax=axs[1])

fig.suptitle("Class repartition before and after oversampling using smote")
a1=fig.axes[0]
a1.set_title("Before")
a2=fig.axes[1]
a2.set_title("After")
# Out:
# Text(0.5, 1.0, 'After')

# %% [markdown]
# # By RandomForestClassifier

# %%
model_rf = RandomForestClassifier(random_state=42)
model_rf.fit(X_resampled_smote, y_resampled_smote)
y_pred_rf = model_rf.predict(xtest)

# %%
print("\nRandomForestClassifier By Smote Results:")
print("Confusion Matrix:\n", confusion_matrix(ytest, y_pred_rf))
print("Classification Report:\n", classification_report(ytest, y_pred_rf))
# Out:
# RandomForestClassifier By Smote Results:
# Confusion Matrix:
#  [[28432     3]
#  [    7    39]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     28435
#            1       0.93      0.85      0.89        46
#
#     accuracy                           1.00     28481
#    macro avg       0.96      0.92      0.94     28481
# weighted avg       1.00      1.00      1.00     28481

# %%
accuracy_s_rf = accuracy_score(ytest, y_pred_rf)
precision_s_rf = precision_score(ytest, y_pred_rf)
recall_s_rf = recall_score(ytest, y_pred_rf)
f1_s_rf = f1_score(ytest, y_pred_rf)
roc_auc_s_rf = roc_auc_score(ytest, y_pred_rf)

# %%
print("RandomForestClassifier By Smote:")
print(f"Accuracy: {accuracy_s_rf:.4f}, Precision: {precision_s_rf:.4f}, Recall: {recall_s_rf:.4f}, F1 Score: {f1_s_rf:.4f}, ROC AUC: {roc_auc_s_rf:.4f}\n")
# Out:
# RandomForestClassifier By Smote:
# Accuracy: 0.9996, Precision: 0.9286, Recall: 0.8478, F1 Score: 0.8864, ROC AUC: 0.9239

# %%
from sklearn.metrics import confusion_matrix

matrix = confusion_matrix(ytest, y_pred_rf)
cm = pd.DataFrame(matrix, index=['not_fraud', 'fraud'], columns=['not_fraud', 'fraud'])

sns.heatmap(cm, annot=True, cbar=None, cmap="Blues", fmt = 'g')

plt.title("Confusion Matrix of RandomForestClassifier By Smote")
plt.tight_layout()
plt.ylabel("True Class")
plt.xlabel("Predicted Class")
plt.show()

# %% [markdown]
# # By SVM

# %%
svm_model = SVC()
svm_model.fit(X_resampled_smote, y_resampled_smote)
y_pred_svm = svm_model.predict(xtest)

# %%
print("\nSVM By Smote Results:")
print("Confusion Matrix:\n", confusion_matrix(ytest, y_pred_svm))
print("Classification Report:\n", classification_report(ytest, y_pred_svm))
# Out:
# SVM By Smote Results:
# Confusion Matrix:
#  [[28149   286]
#  [    7    39]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99     28435
#            1       0.12      0.85      0.21        46
#
#     accuracy                           0.99     28481
#    macro avg       0.56      0.92      0.60     28481
# weighted avg       1.00      0.99      0.99     28481

# %%
accuracy_s_svm = accuracy_score(ytest, y_pred_svm)
precision_s_svm = precision_score(ytest, y_pred_svm)
recall_s_svm = recall_score(ytest, y_pred_svm)
f1_s_svm = f1_score(ytest, y_pred_svm)
roc_auc_s_svm = roc_auc_score(ytest, y_pred_svm)

# %%
print("SVM:")
print(f"Accuracy: {accuracy_s_svm:.4f}, Precision: {precision_s_svm:.4f}, Recall: {recall_s_svm:.4f}, F1 Score: {f1_s_svm:.4f}, ROC AUC: {roc_auc_s_svm:.4f}\n")
# Out:
# SVM:
# Accuracy: 0.9897, Precision: 0.1200, Recall: 0.8478, F1 Score: 0.2102, ROC AUC: 0.9189

# %%
from sklearn.metrics import confusion_matrix

matrix = confusion_matrix(ytest, y_pred_svm)
cm = pd.DataFrame(matrix, index=['not_fraud', 'fraud'], columns=['not_fraud', 'fraud'])

sns.heatmap(cm, annot=True, cbar=None, cmap="Blues", fmt = 'g')

plt.title("Confusion Matrix SVM By Smote")
plt.tight_layout()
plt.ylabel("True Class")
plt.xlabel("Predicted Class")
plt.show()

# %% [markdown]
# # By Logistic Regression

# %%
lr_model = LogisticRegression()
lr_model.fit(X_resampled_smote, y_resampled_smote)
y_pred_lr = lr_model.predict(xtest)
# Out:
# C:\Users\akans\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
print("\nLogistic Regression By Smote Results:")
print("Confusion Matrix:\n", confusion_matrix(ytest, y_pred_lr))
print("Classification Report:\n", classification_report(ytest, y_pred_lr))
# Out:
# Logistic Regression By Smote Results:
# Confusion Matrix:
#  [[27896   539]
#  [    5    41]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     28435
#            1       0.07      0.89      0.13        46
#
#     accuracy                           0.98     28481
#    macro avg       0.54      0.94      0.56     28481
# weighted avg       1.00      0.98      0.99     28481

# %%
accuracy_s_lr = accuracy_score(ytest, y_pred_lr)
precision_s_lr = precision_score(ytest, y_pred_lr)
recall_s_lr = recall_score(ytest, y_pred_lr)
f1_s_lr = f1_score(ytest, y_pred_lr)
roc_auc_s_lr = roc_auc_score(ytest, y_pred_lr)

# %%
print("Logistic Regression using smote:")
print(f"Accuracy: {accuracy_s_lr:.4f}, Precision: {precision_s_lr:.4f}, Recall: {recall_s_lr:.4f}, F1 Score: {f1_s_lr:.4f}, ROC AUC: {roc_auc_s_lr:.4f}\n")
# Out:
# Logistic Regression using smote:
# Accuracy: 0.9809, Precision: 0.0707, Recall: 0.8913, F1 Score: 0.1310, ROC AUC: 0.9362

# %%
from sklearn.metrics import confusion_matrix

matrix = confusion_matrix(ytest, y_pred_lr)
cm = pd.DataFrame(matrix, index=['not_fraud', 'fraud'], columns=['not_fraud', 'fraud'])

sns.heatmap(cm, annot=True, cbar=None, cmap="Blues", fmt = 'g')

plt.title("Confusion Matrix Logistic Regression By Smote")
plt.tight_layout()
plt.ylabel("True Class")
plt.xlabel("Predicted Class")
plt.show()

# %% [markdown]
# # By KNN

# %%
knn_model = KNeighborsClassifier()
knn_model.fit(X_resampled_smote, y_resampled_smote)
y_pred_knn = knn_model.predict(xtest)

# %%
print("\nKNN By Smote Results:")
print("Confusion Matrix:\n", confusion_matrix(ytest, y_pred_knn))
print("Classification Report:\n", classification_report(ytest, y_pred_knn))
# Out:
# KNN By Smote Results:
# Confusion Matrix:
#  [[28366    69]
#  [    9    37]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     28435
#            1       0.35      0.80      0.49        46
#
#     accuracy                           1.00     28481
#    macro avg       0.67      0.90      0.74     28481
# weighted avg       1.00      1.00      1.00     28481

# %%
accuracy_s_knn = accuracy_score(ytest, y_pred_knn)
precision_s_knn = precision_score(ytest, y_pred_knn)
recall_s_knn = recall_score(ytest, y_pred_knn)
f1_s_knn = f1_score(ytest, y_pred_knn)
roc_auc_s_knn = roc_auc_score(ytest, y_pred_knn)

# %%
print("k-Nearest Neighbors (KNN):")
print(f"Accuracy: {accuracy_s_knn:.4f}, Precision: {precision_s_knn:.4f}, Recall: {recall_s_knn:.4f}, F1 Score: {f1_s_knn:.4f}, ROC AUC: {roc_auc_s_knn:.4f}\n")
# Out:
# k-Nearest Neighbors (KNN):
# Accuracy: 0.9973, Precision: 0.3491, Recall: 0.8043, F1 Score: 0.4868, ROC AUC: 0.9010

# %%
from sklearn.metrics import confusion_matrix

matrix = confusion_matrix(ytest, y_pred_knn)
cm = pd.DataFrame(matrix, index=['not_fraud', 'fraud'], columns=['not_fraud', 'fraud'])

sns.heatmap(cm, annot=True, cbar=None, cmap="Blues", fmt = 'g')

plt.title("Confusion Matrix KNN By Smote")
plt.tight_layout()
plt.ylabel("True Class")
plt.xlabel("Predicted Class")
plt.show()

# %% [markdown]
# # Undersampling using Tomek Links

# %%
tl = TomekLinks(sampling_strategy='auto')
X_resampled_tl, y_resampled_tl = tl.fit_resample(xtrain, ytrain)

# %%
test = pd.DataFrame(y_resampled_tl, columns = ['Class'])

# %%
fig, axs = plt.subplots(ncols=2, figsize=(13,4.5))
sns.countplot(x="Class", data=data, ax=axs[0])
sns.countplot(x="Class", data=test, ax=axs[1])

fig.suptitle("Class repartition before and after undersampling using Tomek Links")
a1=fig.axes[0]
a1.set_title("Before")
a2=fig.axes[1]
a2.set_title("After")
# Out:
# Text(0.5, 1.0, 'After')

# %% [markdown]
# # By RandomForestClassifier

# %%
model_rf = RandomForestClassifier(random_state=42)
model_rf.fit(X_resampled_tl, y_resampled_tl)
y_pred_rf = model_rf.predict(xtest)

# %%
print("\nRandomForestClassifier By Tomek Links Results:")
print("Confusion Matrix:\n", confusion_matrix(ytest, y_pred_rf))
print("Classification Report:\n", classification_report(ytest, y_pred_rf))
# Out:
# RandomForestClassifier By Tomek Links Results:
# Confusion Matrix:
#  [[28434     1]
#  [   11    35]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     28435
#            1       0.97      0.76      0.85        46
#
#     accuracy                           1.00     28481
#    macro avg       0.99      0.88      0.93     28481
# weighted avg       1.00      1.00      1.00     28481

# %%
accuracy_t_rf = accuracy_score(ytest, y_pred_rf)
precision_t_rf = precision_score(ytest, y_pred_rf)
recall_t_rf = recall_score(ytest, y_pred_rf)
f1_t_rf = f1_score(ytest, y_pred_rf)
roc_auc_t_rf = roc_auc_score(ytest, y_pred_rf)

# %%
print("RandomForestClassifier By Tomek Links Results:")
print(f"Accuracy: {accuracy_t_rf:.4f}, Precision: {precision_t_rf:.4f}, Recall: {recall_t_rf:.4f}, F1 Score: {f1_t_rf:.4f}, ROC AUC: {roc_auc_t_rf:.4f}\n")
# Out:
# RandomForestClassifier By Tomek Links Results:
# Accuracy: 0.9996, Precision: 0.9722, Recall: 0.7609, F1 Score: 0.8537, ROC AUC: 0.8804

# %%
from sklearn.metrics import confusion_matrix

matrix = confusion_matrix(ytest, y_pred_rf)
cm = pd.DataFrame(matrix, index=['not_fraud', 'fraud'], columns=['not_fraud', 'fraud'])

sns.heatmap(cm, annot=True, cbar=None, cmap="Blues", fmt = 'g')

plt.title("Confusion Matrix of RandomForestClassifier By Tomek Linkss")
plt.tight_layout()
plt.ylabel("True Class")
plt.xlabel("Predicted Class")
plt.show()

# %% [markdown]
# # By SVM

# %%
svm_model = SVC()
svm_model.fit(X_resampled_tl, y_resampled_tl)
y_pred_svm = svm_model.predict(xtest)

# %%
print("\nSVM By Tomek Links Results:")
print("Confusion Matrix:\n", confusion_matrix(ytest, y_pred_svm))
print("Classification Report:\n", classification_report(ytest, y_pred_svm))
# Out:
# SVM By Tomek Links Results:
# Confusion Matrix:
#  [[28429     6]
#  [   27    19]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     28435
#            1       0.76      0.41      0.54        46
#
#     accuracy                           1.00     28481
#    macro avg       0.88      0.71      0.77     28481
# weighted avg       1.00      1.00      1.00     28481

# %%
accuracy_t_svm = accuracy_score(ytest, y_pred_svm)
precision_t_svm = precision_score(ytest, y_pred_svm)
recall_t_svm = recall_score(ytest, y_pred_svm)
f1_t_svm = f1_score(ytest, y_pred_svm)
roc_auc_t_svm = roc_auc_score(ytest, y_pred_svm)

# %%
print("SVM:")
print(f"Accuracy: {accuracy_t_svm:.4f}, Precision: {precision_t_svm:.4f}, Recall: {recall_t_svm:.4f}, F1 Score: {f1_t_svm:.4f}, ROC AUC: {roc_auc_t_svm:.4f}\n")
# Out:
# SVM:
# Accuracy: 0.9988, Precision: 0.7600, Recall: 0.4130, F1 Score: 0.5352, ROC AUC: 0.7064

# %%
from sklearn.metrics import confusion_matrix

matrix = confusion_matrix(ytest, y_pred_svm)
cm = pd.DataFrame(matrix, index=['not_fraud', 'fraud'], columns=['not_fraud', 'fraud'])

sns.heatmap(cm, annot=True, cbar=None, cmap="Blues", fmt = 'g')

plt.title("Confusion Matrix SVM By Tomek Links")
plt.tight_layout()
plt.ylabel("True Class")
plt.xlabel("Predicted Class")
plt.show()

# %% [markdown]
# # lr

# %%
lr_model = LogisticRegression()
lr_model.fit(X_resampled_tl, y_resampled_tl)
y_pred_lr = lr_model.predict(xtest)
# Out:
# C:\Users\akans\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
print("\nLogistic Regression By Tomek Links Results:")
print("Confusion Matrix:\n", confusion_matrix(ytest, y_pred_lr))
print("Classification Report:\n", classification_report(ytest, y_pred_lr))
# Out:
# Logistic Regression By Tomek Links Results:
# Confusion Matrix:
#  [[28427     8]
#  [   18    28]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     28435
#            1       0.78      0.61      0.68        46
#
#     accuracy                           1.00     28481
#    macro avg       0.89      0.80      0.84     28481
# weighted avg       1.00      1.00      1.00     28481

# %%
accuracy_t_lr = accuracy_score(ytest, y_pred_lr)
precision_t_lr = precision_score(ytest, y_pred_lr)
recall_t_lr = recall_score(ytest, y_pred_lr)
f1_t_lr = f1_score(ytest, y_pred_lr)
roc_auc_t_lr = roc_auc_score(ytest, y_pred_lr)

# %%
print("Logistic Regression:")
print(f"Accuracy: {accuracy_t_lr:.4f}, Precision: {precision_t_lr:.4f}, Recall: {recall_t_lr:.4f}, F1 Score: {f1_t_lr:.4f}, ROC AUC: {roc_auc_t_lr:.4f}\n")
# Out:
# Logistic Regression:
# Accuracy: 0.9991, Precision: 0.7778, Recall: 0.6087, F1 Score: 0.6829, ROC AUC: 0.8042

# %%
from sklearn.metrics import confusion_matrix

matrix = confusion_matrix(ytest, y_pred_lr)
cm = pd.DataFrame(matrix, index=['not_fraud', 'fraud'], columns=['not_fraud', 'fraud'])

sns.heatmap(cm, annot=True, cbar=None, cmap="Blues", fmt = 'g')

plt.title("Confusion Matrix Logistic Regression By Tomek Links")
plt.tight_layout()
plt.ylabel("True Class")
plt.xlabel("Predicted Class")
plt.show()

# %% [markdown]
# # By KNN

# %%
knn_model = KNeighborsClassifier()
knn_model.fit(X_resampled_tl, y_resampled_tl)
y_pred_knn = knn_model.predict(xtest)

# %%
print("\nKNN By Tomek Links Results:")
print("Confusion Matrix:\n", confusion_matrix(ytest, y_pred_knn))
print("Classification Report:\n", classification_report(ytest, y_pred_knn))
# Out:
# KNN By Tomek Links Results:
# Confusion Matrix:
#  [[28434     1]
#  [   18    28]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     28435
#            1       0.97      0.61      0.75        46
#
#     accuracy                           1.00     28481
#    macro avg       0.98      0.80      0.87     28481
# weighted avg       1.00      1.00      1.00     28481

# %%
accuracy_t_knn = accuracy_score(ytest, y_pred_knn)
precision_t_knn = precision_score(ytest, y_pred_knn)
recall_t_knn = recall_score(ytest, y_pred_knn)
f1_t_knn = f1_score(ytest, y_pred_knn)
roc_auc_t_knn = roc_auc_score(ytest, y_pred_knn)

# %%
print("k-Nearest Neighbors (KNN):")
print(f"Accuracy: {accuracy_t_knn:.4f}, Precision: {precision_t_knn:.4f}, Recall: {recall_t_knn:.4f}, F1 Score: {f1_t_knn:.4f}, ROC AUC: {roc_auc_t_knn:.4f}\n")
# Out:
# k-Nearest Neighbors (KNN):
# Accuracy: 0.9993, Precision: 0.9655, Recall: 0.6087, F1 Score: 0.7467, ROC AUC: 0.8043

# %%
from sklearn.metrics import confusion_matrix

matrix = confusion_matrix(ytest, y_pred_knn)
cm = pd.DataFrame(matrix, index=['not_fraud', 'fraud'], columns=['not_fraud', 'fraud'])

sns.heatmap(cm, annot=True, cbar=None, cmap="Blues", fmt = 'g')

plt.title("Confusion Matrix KNN By Tomek Links")
plt.tight_layout()
plt.ylabel("True Class")
plt.xlabel("Predicted Class")
plt.show()

# %% [markdown]
# # Undersampling using NearMiss

# %%
nm = NearMiss(sampling_strategy='auto')
X_resampled_nm, y_resampled_nm = nm.fit_resample(xtrain, ytrain)

# %%
test = pd.DataFrame(y_resampled_nm, columns = ['Class'])

# %%
fig, axs = plt.subplots(ncols=2, figsize=(13,4.5))
sns.countplot(x="Class", data=data, ax=axs[0])
sns.countplot(x="Class", data=test, ax=axs[1])

fig.suptitle("Class repartition before and after undersampling using NearMiss")
a1=fig.axes[0]
a1.set_title("Before")
a2=fig.axes[1]
a2.set_title("After")
# Out:
# Text(0.5, 1.0, 'After')

# %% [markdown]
# # By RandomForestClassifier

# %%
model_rf = RandomForestClassifier(random_state=42)
model_rf.fit(X_resampled_nm, y_resampled_nm)
y_pred_rf = model_rf.predict(xtest)

# %%
print("\nRandomForestClassifier By NearMiss Results:")
print("Confusion Matrix:\n", confusion_matrix(ytest, y_pred_rf))
print("Classification Report:\n", classification_report(ytest, y_pred_rf))
# Out:
# RandomForestClassifier By NearMiss Results:
# Confusion Matrix:
#  [[  206 28229]
#  [    0    46]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.01      0.01     28435
#            1       0.00      1.00      0.00        46
#
#     accuracy                           0.01     28481
#    macro avg       0.50      0.50      0.01     28481
# weighted avg       1.00      0.01      0.01     28481

# %%
accuracy_n_rf = accuracy_score(ytest, y_pred_rf)
precision_n_rf = precision_score(ytest, y_pred_rf)
recall_n_rf = recall_score(ytest, y_pred_rf)
f1_n_rf = f1_score(ytest, y_pred_rf)
roc_auc_n_rf = roc_auc_score(ytest, y_pred_rf)

# %%
print("RandomForestClassifier:")
print(f"Accuracy: {accuracy_n_rf:.4f}, Precision: {precision_n_rf:.4f}, Recall: {recall_n_rf:.4f}, F1 Score: {f1_n_rf:.4f}, ROC AUC: {roc_auc_n_rf:.4f}\n")
# Out:
# RandomForestClassifier:
# Accuracy: 0.0088, Precision: 0.0016, Recall: 1.0000, F1 Score: 0.0032, ROC AUC: 0.5036

# %%
from sklearn.metrics import confusion_matrix

matrix = confusion_matrix(ytest, y_pred_rf)
cm = pd.DataFrame(matrix, index=['not_fraud', 'fraud'], columns=['not_fraud', 'fraud'])

sns.heatmap(cm, annot=True, cbar=None, cmap="Blues", fmt = 'g')

plt.title("Confusion Matrix of RandomForestClassifier By NearMiss")
plt.tight_layout()
plt.ylabel("True Class")
plt.xlabel("Predicted Class")
plt.show()

# %% [markdown]
# # By SVM

# %%
svm_model = SVC()
svm_model.fit(X_resampled_nm, y_resampled_nm)
y_pred_svm = svm_model.predict(xtest)

# %%
print("\nSVM By NearMiss Results:")
print("Confusion Matrix:\n", confusion_matrix(ytest, y_pred_svm))
print("Classification Report:\n", classification_report(ytest, y_pred_svm))
# Out:
# SVM By NearMiss Results:
# Confusion Matrix:
#  [[15352 13083]
#  [    7    39]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.54      0.70     28435
#            1       0.00      0.85      0.01        46
#
#     accuracy                           0.54     28481
#    macro avg       0.50      0.69      0.35     28481
# weighted avg       1.00      0.54      0.70     28481

# %%
accuracy_n_svm = accuracy_score(ytest, y_pred_svm)
precision_n_svm = precision_score(ytest, y_pred_svm)
recall_n_svm = recall_score(ytest, y_pred_svm)
f1_n_svm = f1_score(ytest, y_pred_svm)
roc_auc_n_svm = roc_auc_score(ytest, y_pred_svm)

# %%
print("SVM:")
print(f"Accuracy: {accuracy_n_svm:.4f}, Precision: {precision_n_svm:.4f}, Recall: {recall_n_svm:.4f}, F1 Score: {f1_n_svm:.4f}, ROC AUC: {roc_auc_n_svm:.4f}\n")
# Out:
# SVM:
# Accuracy: 0.5404, Precision: 0.0030, Recall: 0.8478, F1 Score: 0.0059, ROC AUC: 0.6939

# %%
from sklearn.metrics import confusion_matrix

matrix = confusion_matrix(ytest, y_pred_svm)
cm = pd.DataFrame(matrix, index=['not_fraud', 'fraud'], columns=['not_fraud', 'fraud'])

sns.heatmap(cm, annot=True, cbar=None, cmap="Blues", fmt = 'g')

plt.title("Confusion Matrix SVM By NearMiss")
plt.tight_layout()
plt.ylabel("True Class")
plt.xlabel("Predicted Class")
plt.show()

# %% [markdown]
# # By LogisticRegression

# %%
lr_model = LogisticRegression()
lr_model.fit(X_resampled_nm, y_resampled_nm)
y_pred_lr = lr_model.predict(xtest)

# %%
print("\nLogistic Regression By NearMiss Results:")
print("Confusion Matrix:\n", confusion_matrix(ytest, y_pred_lr))
print("Classification Report:\n", classification_report(ytest, y_pred_lr))
# Out:
# Logistic Regression By NearMiss Results:
# Confusion Matrix:
#  [[ 3974 24461]
#  [    0    46]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.14      0.25     28435
#            1       0.00      1.00      0.00        46
#
#     accuracy                           0.14     28481
#    macro avg       0.50      0.57      0.12     28481
# weighted avg       1.00      0.14      0.24     28481

# %%
accuracy_n_lr = accuracy_score(ytest, y_pred_lr)
precision_n_lr = precision_score(ytest, y_pred_lr)
recall_n_lr = recall_score(ytest, y_pred_lr)
f1_n_lr = f1_score(ytest, y_pred_lr)
roc_auc_n_lr = roc_auc_score(ytest, y_pred_lr)

# %%
print("Logistic Regression:")
print(f"Accuracy: {accuracy_n_lr:.4f}, Precision: {precision_n_lr:.4f}, Recall: {recall_n_lr:.4f}, F1 Score: {f1_n_lr:.4f}, ROC AUC: {roc_auc_n_lr:.4f}\n")
# Out:
# Logistic Regression:
# Accuracy: 0.1411, Precision: 0.0019, Recall: 1.0000, F1 Score: 0.0037, ROC AUC: 0.5699

# %%
from sklearn.metrics import confusion_matrix

matrix = confusion_matrix(ytest, y_pred_lr)
cm = pd.DataFrame(matrix, index=['not_fraud', 'fraud'], columns=['not_fraud', 'fraud'])

sns.heatmap(cm, annot=True, cbar=None, cmap="Blues", fmt = 'g')

plt.title("Confusion Matrix Logistic Regression By NearMiss")
plt.tight_layout()
plt.ylabel("True Class")
plt.xlabel("Predicted Class")
plt.show()

# %% [markdown]
# # KNN

# %%
knn_model = KNeighborsClassifier()
knn_model.fit(X_resampled_nm, y_resampled_nm)
y_pred_knn = knn_model.predict(xtest)

# %%
print("\nKNN By NearMiss Results:")
print("Confusion Matrix:\n", confusion_matrix(ytest, y_pred_knn))
print("Classification Report:\n", classification_report(ytest, y_pred_knn))
# Out:
# KNN By NearMiss Results:
# Confusion Matrix:
#  [[ 5238 23197]
#  [    2    44]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.18      0.31     28435
#            1       0.00      0.96      0.00        46
#
#     accuracy                           0.19     28481
#    macro avg       0.50      0.57      0.16     28481
# weighted avg       1.00      0.19      0.31     28481

# %%
accuracy_n_knn = accuracy_score(ytest, y_pred_knn)
precision_n_knn = precision_score(ytest, y_pred_knn)
recall_n_knn = recall_score(ytest, y_pred_knn)
f1_n_knn = f1_score(ytest, y_pred_knn)
roc_auc_n_knn = roc_auc_score(ytest, y_pred_knn)

# %%
print("k-Nearest Neighbors (KNN):")
print(f"Accuracy: {accuracy_n_knn:.4f}, Precision: {precision_n_knn:.4f}, Recall: {recall_n_knn:.4f}, F1 Score: {f1_n_knn:.4f}, ROC AUC: {roc_auc_n_knn:.4f}\n")
# Out:
# k-Nearest Neighbors (KNN):
# Accuracy: 0.1855, Precision: 0.0019, Recall: 0.9565, F1 Score: 0.0038, ROC AUC: 0.5704

# %%
from sklearn.metrics import confusion_matrix

matrix = confusion_matrix(ytest, y_pred_knn)
cm = pd.DataFrame(matrix, index=['not_fraud', 'fraud'], columns=['not_fraud', 'fraud'])

sns.heatmap(cm, annot=True, cbar=None, cmap="Blues", fmt = 'g')

plt.title("Confusion Matrix KNN By NearMiss")
plt.tight_layout()
plt.ylabel("True Class")
plt.xlabel("Predicted Class")
plt.show()

# %%
randomforestclassifier-0.9995435553526912

Randomundersampling,randomforest cassifier-0.9744
Oversampling using SMOTE:randomforest classifier-0.9996
Undersampling using Tomek Links:randomforest classifier-0.9996
Undersampling using NearMiss:SVM-0.5404

# %%
import matplotlib.pyplot as plt

algorithms = ['randomforestclassifier', 'Logistic Regression by Randomundersampling', 'Oversampling using SMOTE:randomforest classifier', 'Undersampling using Tomek Links:randomforest classifier', 'Undersampling using NearMiss:SVM']
accuracy_values = [accuracy_rf, accuracy_u_lr,accuracy_s_rf,accuracy_t_rf,accuracy_n_svm]  

plt.barh(algorithms, accuracy_values, color=['blue', 'green', 'orange', 'red', 'purple'])
plt.xlabel('Accuracy')
plt.ylabel('Algorithms')
plt.title('Accuracy Comparison of Algorithms')

for i, v in enumerate(accuracy_values):
    plt.text(v, i, f'{v:.2f}', va='center', fontsize=10, color='black', ha='left')

plt.show()

# %%
import matplotlib.pyplot as plt

algorithms = ['randomforestclassifier', 'Logistic Regression by Randomundersampling', 'Oversampling using SMOTE:randomforest classifier', 'Undersampling using Tomek Links:randomforest classifier', 'Undersampling using NearMiss:SVM']
precision_values = [precision_rf, precision_u_lr,precision_s_rf,precision_t_rf,precision_n_svm]

plt.barh(algorithms, precision_values, color=['blue', 'green', 'orange', 'red', 'purple'])
plt.xlabel('Precision')
plt.ylabel('Algorithms')
plt.title('Precision Comparison of Algorithms')


for i, v in enumerate(precision_values):
    plt.text(v, i, f'{v:.2f}', va='center', fontsize=10, color='black', ha='left')

plt.show()

# %%
import matplotlib.pyplot as plt

algorithms = ['randomforestclassifier', 'Logistic Regression by Randomundersampling', 'Oversampling using SMOTE:randomforest classifier', 'Undersampling using Tomek Links:randomforest classifier', 'Undersampling using NearMiss:SVM']
recall_values = [recall_rf, recall_u_lr,recall_s_rf,recall_t_rf,recall_n_svm] 

plt.barh(algorithms, recall_values, color=['blue', 'green', 'orange', 'red', 'purple'])
plt.xlabel('recall')
plt.ylabel('Algorithms')
plt.title('Recall Comparison of Algorithms')

for i, v in enumerate(recall_values):
    plt.text(v, i, f'{v:.2f}', va='center', fontsize=10, color='black', ha='left')

plt.show()

# %%
import matplotlib.pyplot as plt

algorithms = ['randomforestclassifier', 'Logistic Regression by Randomundersampling', 'Oversampling using SMOTE:randomforest classifier', 'Undersampling using Tomek Links:randomforest classifier', 'Undersampling using NearMiss:SVM']
f1_values = [f1_rf, f1_u_lr,f1_s_rf,f1_t_rf,f1_n_svm] 

plt.barh(algorithms, f1_values, color=['blue', 'green', 'orange', 'red', 'purple'])
plt.xlabel('f1 score')
plt.ylabel('Algorithms')
plt.title('f1 score Comparison of Algorithms')

for i, v in enumerate(f1_values):
    plt.text(v, i, f'{v:.2f}', va='center', fontsize=10, color='black', ha='left')

plt.show()

# %%
import matplotlib.pyplot as plt

algorithms = ['randomforestclassifier', 'Logistic Regression by Randomundersampling', 'Oversampling using SMOTE:randomforest classifier', 'Undersampling using Tomek Links:randomforest classifier', 'Undersampling using NearMiss:SVM']
roc_auc_values = [roc_auc_rf, roc_auc_u_lr,roc_auc_s_rf,roc_auc_t_rf,roc_auc_n_svm] 

plt.barh(algorithms, roc_auc_values, color=['blue', 'green', 'orange', 'red', 'purple'])
plt.xlabel('roc_auc')
plt.ylabel('Algorithms')
plt.title('roc_auc Comparison of Algorithms')


for i, v in enumerate(roc_auc_values):
    plt.text(v, i, f'{v:.2f}', va='center', fontsize=10, color='black', ha='left')

plt.show()
